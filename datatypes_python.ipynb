# %% [markdown]
# # data types in python
#
# ## python have 3 data types
# 1. int(integer)
# 2. str(string)
# 3. float(decimals)

# %%
name="gnaneshwar"
age=16
salary=500000
print(name)
print(age)
print(salary)
# Out:
# gnaneshwar
# 16
# 500000

# %%
data="120"
print(data)
print(type(data))
# Out:
# 120
# <class 'str'>

# %%
a=100
b=120
print(a+b)
print(type(a+b))
# Out:
# 220
# <class 'int'>

# %%
v1=100
v2=100.5
print(v1+v2)
print(type(v1+v2))
# Out:
# 200.5
# <class 'float'>
