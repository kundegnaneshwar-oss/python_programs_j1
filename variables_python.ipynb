# %% [markdown]
# # variables In python
# 1. variables is memory allocation to value
# 2. examples are name="gnaneshwar",age=16,salary=500000
#
# ## key points to define variables
# 1. variables do not start with digit
# 2. variables does not allowed special charecters
# 3. do not use keywords as a variables

# %%
name="gnaneshwar"
age=16
salary=500000
print(name)
print(age)
print(salary)
# Out:
# gnaneshwar
# 16
# 500000

# %%
1name="gnaneshwar"
print(name)
# Out:
#   Cell In[2], line 1
#     1name="gnaneshwar"
#     ^
# SyntaxError: invalid decimal literal

# %%
name@="gnaneshwar"
print(name@)
# Out:
#   Cell In[3], line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
while="gnanesh"
print(while)
# Out:
#   Cell In[4], line 1
#     while="gnanesh"
#          ^
# SyntaxError: invalid syntax
